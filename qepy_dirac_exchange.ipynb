# %% [markdown]
# # Replace exchange-correlation by Dirac exchange.

# %% [markdown]
# This notebook uses a QEpy **iterative** `Driver` to hand-roll a custom exchange-correlation potential — the Dirac (Slater) exchange functional, exchange only, no correlation — and compares the resulting total energy against a normal black-box SCF run with the pseudopotential's built-in XC.
#
# System: bulk aluminum (FCC, 1 atom/cell).
#
# Steps:
# 1. Run a standard SCF (`driver.scf()`) as a baseline, using the XC functional from the pseudopotential.
# 2. Re-run SCF in `iterative=True` mode, manually substituting the Dirac exchange potential/energy at every cycle via `set_external_potential`.
# 3. Compare the two total energies — the difference reflects the correlation (and any gradient-correction) contribution that pure Dirac exchange omits.</cell id="5d0a114b">

# %%
# --- optional pip installs (normally leave collapsed / do not run) ---
# !pip install qepy
# !pip install matplotlib

# %% [markdown]
# ## 1) Imports
#
# NumPy for the exchange formula, and QEpy's `Driver`/`QEInput` for running SCF. (The ASE/matplotlib imports below are unused in this minimal demo — left over from a template.)

# %%
import numpy as np
from qepy.driver import Driver
from qepy.io import QEInput

# %%
from ase.io.trajectory import Trajectory
from ase.lattice.hexagonal import Graphene
from ase import Atoms
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2) System: bulk aluminum
#
# FCC aluminum, one atom per primitive cell, described with an ONCV PBE pseudopotential. `degauss`/`occupations: smearing` handle the metallic Fermi surface; `ecutwfc=30` Ry and a 4×4×4 k-mesh keep this quick to run.

# %%
qe_options = {
    '&control': {
        'calculation': "'scf'",
        'pseudo_dir': "'./data/'"
    },
    '&system': {
        'ibrav' : 0,
        'degauss': 0.005,
        'ecutwfc': 30,
        'nat': 1,
        'ntyp': 1,
        'occupations': "'smearing'"
    },
    'atomic_positions crystal': ['Al    0.0  0.0  0.0'],
    'atomic_species': ['Al  26.98 Al_ONCV_PBE-1.2.upf'],
    'k_points automatic': ['4 4 4 0 0 0'],
    'cell_parameters angstrom':[
        '0.     2.025  2.025',
        '2.025  0.     2.025',
        '2.025  2.025  0.   '],
}

# %% [markdown]
# ## 3) Baseline SCF with the pseudopotential's default XC
#
# Run a standard, non-iterative SCF (`driver.scf()`) so we have a reference total energy computed with whatever XC functional the pseudopotential specifies.

# %%
driver=Driver(qe_options=qe_options, logfile='tmp.out')

# %%
driver.scf()
# Out:
# -137.91449177036435

# %% [markdown]
# ## 4) Iterative driver for a custom XC
#
# Create a fresh `Driver` with `iterative=True`. This hands the SCF loop to Python — instead of `driver.scf()` running everything internally, we now call `diagonalize()`/`mix()` ourselves each cycle and can inject a custom potential via `set_external_potential` before each step.

# %%
driver=Driver(qe_options=qe_options, iterative = True, logfile='tmp.out')

# %% [markdown]
# ## 5) Dirac (Slater) exchange functional
#
# `diracx` implements the analytic LDA exchange potential and energy for a given density `rho`:
#
# - $V_x(r) = -\left(\frac{3}{\pi}\rho(r)\right)^{1/3}$
# - $E_x = \frac{3}{4}\int V_x(r)\,\rho(r)\,dr$
#
# The `* 2` factors convert from Hartree to Rydberg units, matching QEpy's internal convention (the same convention used by `set_external_potential`).

# %%
def diracx(rho, volume):
    v = -np.cbrt(3.0/np.pi*rho)
    e = np.sum((v*rho))*(3.0/4.0)*volume/rho.size
    return v*2,e*2

# %% [markdown]
# ## 6) Manual SCF loop using Dirac exchange only
#
# Each iteration: get the current density and cell volume, evaluate the Dirac exchange potential/energy, feed it in via `set_external_potential(exttype='xc')` — which **replaces** the pseudopotential's built-in XC entirely, leaving pure exchange with no correlation — then `diagonalize()` and `mix()`. Stop early once `check_convergence()` is satisfied (cap at 60 iterations).

# %%
for i in range(60):
    volume = driver.get_volume()
    extpot, ex = diracx(driver.get_density(), volume)
    driver.set_external_potential(potential=extpot, extene=ex, exttype=('xc'))
    driver.diagonalize()
    driver.mix()
    converged = driver.check_convergence()
    print ('Iter: ',i,' - Conv: ', driver.get_scf_error())
    if converged : break
# Out:
# Iter:  0  - Conv:  0.08502965756511995
# Iter:  1  - Conv:  0.001188255873612242
# Iter:  2  - Conv:  3.068188756668704e-05
# Iter:  3  - Conv:  6.316802803702857e-08

# %% [markdown]
# ## 7) Compare total energies
#
# This final energy (Dirac exchange only) comes out about 1.77 Ry higher than the step-3 baseline — the gap is the correlation (and GGA gradient-correction, if the pseudopotential's default XC is a GGA) contribution that pure Dirac exchange leaves out.

# %%
driver.get_energy()
# Out:
# -136.14656245916035
